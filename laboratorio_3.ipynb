# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2

# %% [markdown]
# ##### Parte 1: Numpy

# %% [markdown]
# 1) ¿Cuál es el tamaño en bytes de un array de 1000
# elementos de tipo booleano?

# %%
array_1 = np.zeros(1000, dtype=bool)

# %%
tamanio_en_bytes = array_1.nbytes

# %%
tamanio_en_bytes
# Out:
# 1000

# %% [markdown]
# 2) Cree un array cuyos elementos sean los enteros pares en
# [1,100] y en orden decreciente. Muestre los 10 últimos
# por pantalla.

# %%
array_2 = np.arange(2, 102, 2)
array_2 = np.sort(array_2)[::-1]

# %%
array_2[-10:]
# Out:
# array([20, 18, 16, 14, 12, 10,  8,  6,  4,  2])

# %% [markdown]
# 3) Dado el array
# 2 4 5 6
# 0 3 7 4
# 8 8 5 2
# 1 5 6 1
# Seleccione con una instrucción el subarray de elementos
# 0 3 7 4
# Después, seleccione el subarray de elementos
# 2 5
# 8 5

# %%
array_3 = np.array([[2,4,5,6], [0,3,7,4], [8,8,5,2], [1,5,6,1]])

# %%
array_3
# Out:
# array([[2, 4, 5, 6],
#        [0, 3, 7, 4],
#        [8, 8, 5, 2],
#        [1, 5, 6, 1]])

# %%
array_3[1]
# Out:
# array([0, 3, 7, 4])

# %%
np.array([[array_3[0][0], array_3[0][2]], [array_3[2][0], array_3[2][2]]])
# Out:
# array([[2, 5],
#        [8, 5]])

# %% [markdown]
# 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9],
# obtenga la media aritmética de la diferencia (a-b).

# %%
array_a = np.array([1,4,2,7])
array_b = np.array([1,3,2,9])

# %%
np.mean(array_a-array_b)
# Out:
# -0.25

# %% [markdown]
# 5) Tengo valores de cordenadas (x, y) en las columnas
# del array
# 1.33 4.5
# 30.0 10.7
# 70.2 0.5
#
# Agregue a este array las coordenadas (37.1, -3.6).
# Muestre en pantalla las dimensiones del nuevo
# array.

# %%
array_5 = np.array([[1.33,4.5], [30.0, 10.7], [70.2, 0.5]])

# %%
array_5
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ]])

# %%
array_coor = np.array([[37.1, -3.6]])

# %%
array_5 = np.concatenate((array_5, array_coor))

# %%
array_5
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %% [markdown]
# 6) Copie el array del ejercicio anterior. Traspóngalo (.
# Agregue ahora dos nuevos pares de coordenadas: (10.8,
# 3.0) y (35.8, 12.0).

# %%
array_coor_2 = np.array([[10.8, 3.0], [35.8, 12.0]])

# %%
array_6 = np.concatenate((array_5, array_coor_2))

# %%
array_6
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ],
#        [10.8 ,  3.  ],
#        [35.8 , 12.  ]])

# %% [markdown]
# ##### Parte 2: Exploraciòn y Minerìa de Datos

# %%
data = pd.read_csv("NucleosPoblacion.csv")

# %%
data
# Out:
#      FID  OBJECTID                           Texto  Poblacion  CodMun  \
# 0      0         1                         Agüimes    29431.0   35002
# 1      1         2                         Antigua    10458.0   35003
# 2      2         3                        Arrecife    58156.0   35004
# 3      3         4                          Arucas    36745.0   35006
# 4      4         5                          Gáldar    24473.0   35009
# ..   ...       ...                             ...        ...     ...
# 847  847       848             Infante Juan Manuel    14192.0   30030
# 848  848       849           Santa Maria de Gracia    13349.0   30030
# 849  849       850                    Vista Alegre    15208.0   30030
# 850  850       851  Poligono Sta M de Benquerencia    19177.0   45168
# 851  851       852                            Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 0                                       Agüimes         35
# 1                                       Antigua         35
# 2                                      Arrecife         35
# 3                                        Arucas         35
# 4                                        Gáldar         35
# ..                                          ...        ...
# 847                                      Murcia         30
# 848                                      Murcia         30
# 849                                      Murcia         30
# 850                                      Toledo         45
# 851  Castellón de la Plana/Castelló de la Plana         12
#
#               Provincia          X          Y
# 0            Las Palmas -15.446012  27.900542
# 1            Las Palmas -14.013301  28.418966
# 2            Las Palmas -13.551451  28.960649
# 3            Las Palmas -15.521512  28.117496
# 4            Las Palmas -15.654111  28.143873
# ..                  ...        ...        ...
# 847              Murcia  -1.124304  37.979033
# 848              Murcia  -1.202069  37.984024
# 849              Murcia  -1.130564  37.995715
# 850              Toledo  -3.948364  39.866699
# 851  Castelló/Castellón   0.012911  39.973568
#
# [852 rows x 10 columns]

# %% [markdown]
# 1) ¿Cuántos Municipios tienen más de 100000
# habitantes?.

# %%
data_1 = data.groupby("Municipio").sum("Poblacion")

# %%
data_1[data_1["Poblacion"]>100000].count()["FID"]
# Out:
# 75

# %% [markdown]
# R. 75 municipios tienen màs de 100,000 habitantes

# %% [markdown]
# 2) Realice una gráfica de barras sobre la población de cada
# ciudad, ordenela de menor a mayor y responda:
# a. ¿Cuál es la segunda ciudad más poblada?
# b. ¿Qué posición ocupa Granada en el ranking de
# las ciudades más pobladas?

# %%
data_2 = data.sort_values("Poblacion", ascending=False)

# %%
plt.figure(figsize=(20,10))
plt.bar(data_2["Provincia"], data_2["Poblacion"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# R. La segunda ciudad màs poblada es Barcelona, Granada ocupa el puesto 17

# %% [markdown]
# 3) ¿Cuántos municipios de Extremadura tienen más de 5000
# habitantes?.

# %%
provincinas_extremadura = ["Badajoz", "Cáceres"]

data_3 = data[data["Provincia"].isin(provincinas_extremadura)]

# %%
data_3 = data_3.groupby("Municipio").sum("Poblacion")

# %%
data_3[data_3["Poblacion"]>5000].count()["FID"]
# Out:
# 14

# %% [markdown]
# R. 14 municipios de Extremadura tienen màs de 5,000 habitantes

# %% [markdown]
# 4) ¿Cuál es el municipio situado más al Norte? (Usar el
# valor de la coordenada "Y" que representa la latitud en
# grados). Proporcione también la provincia a la que
# pertenece y su población.

# %%
data_4 = data[data["Y"]==data["Y"].max()][["Municipio", "Provincia", "Poblacion"]]

# %% [markdown]
# R. El municipio màs al norte es Viveiro

# %%
data_4
# Out:
#     Municipio Provincia  Poblacion
# 104   Viveiro      Lugo    16211.0

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor
# máximo y valor mínimo de la población de los municipios
# de la provincia de Granada.

# %%
data_5 = data[data["Provincia"]=="Granada"]

# %% [markdown]
# R. los datos descriptivos de la provincia de Granada son

# %%
data_5["Poblacion"].describe()
# Out:
# count        20.000000
# mean      30217.850000
# std       50355.491715
# min       10386.000000
# 25%       13146.500000
# 50%       17526.000000
# 75%       21739.750000
# max      239154.000000
# Name: Poblacion, dtype: float64

# %% [markdown]
# 6) Realice un histograma con la población de los
# Municipios para cada una de las provincias.

# %%
lista_provincias = data["Provincia"].unique().tolist()

# %%
for prov in lista_provincias:

    data_6 = data[data["Provincia"]==prov]

    plt.hist(data_6["Municipio"], weights=data_6["Poblacion"])

    plt.title("Poblacion por municipo de " + str(prov))

    plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de
# entre los diponibles en el archivo. Asegúrese de que no
# se repitan. ¿Luego calcule el promedio de la población y
# la desviación estándar de esto 50 municipios?.

# %%
data_7 = data.groupby("Municipio").sum("Poblacion")

# %%
data_7 = data_7.sample(50)

# %% [markdown]
# R. Media de los municipios seleccionados

# %%
data_7["Poblacion"].mean()
# Out:
# 39847.9

# %% [markdown]
# R. Desviaciòn Estandar de los municipios seleccionados

# %%
data["Poblacion"].std()
# Out:
# 140598.14339650262

# %% [markdown]
# 8) Dígame los nombres de los Municipios más cercano y más
# lejano a Madrid. Para ello debe calcular la distancia en
# todos ellos y Madrid. No considere a Madrid en el
# análisis ya que la distancia sería cero.

# %%
coordenadas_madrid = data[["Y", "X"]][data["Municipio"]=="Madrid"]

# %%
coordenadas_madrid
# Out:
#             Y         X
# 355  40.41663 -3.703797

# %%
data_8 = data[data["Municipio"]!="Madrid"].merge(coordenadas_madrid, how='cross')

# %%
def distancia(lat1, lon1, lat2, lon2):
    R = 6373.0 

    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    lon = lon2 - lon1
    lat = lat2 - lat1

    a = sin(lat / 2)**2 + cos(lat1) * cos(lat2) * sin(lon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distancia = R * c

    return distancia

# %%
data_8['distancia_a_madrid'] = data_8.apply(lambda row: distancia(row['Y_x'], row['X_x'], row['Y_y'], row['X_y']), axis=1)

# %%
data_8
# Out:
#      FID  OBJECTID                           Texto  Poblacion  CodMun  \
# 0      0         1                         Agüimes    29431.0   35002
# 1      1         2                         Antigua    10458.0   35003
# 2      2         3                        Arrecife    58156.0   35004
# 3      3         4                          Arucas    36745.0   35006
# 4      4         5                          Gáldar    24473.0   35009
# ..   ...       ...                             ...        ...     ...
# 846  847       848             Infante Juan Manuel    14192.0   30030
# 847  848       849           Santa Maria de Gracia    13349.0   30030
# 848  849       850                    Vista Alegre    15208.0   30030
# 849  850       851  Poligono Sta M de Benquerencia    19177.0   45168
# 850  851       852                            Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 0                                       Agüimes         35
# 1                                       Antigua         35
# 2                                      Arrecife         35
# 3                                        Arucas         35
# 4                                        Gáldar         35
# ..                                          ...        ...
# 846                                      Murcia         30
# 847                                      Murcia         30
# 848                                      Murcia         30
# 849                                      Toledo         45
# 850  Castellón de la Plana/Castelló de la Plana         12
#
#               Provincia        X_x        Y_x       Y_y       X_y  \
# 0            Las Palmas -15.446012  27.900542  40.41663 -3.703797
# 1            Las Palmas -14.013301  28.418966  40.41663 -3.703797
# 2            Las Palmas -13.551451  28.960649  40.41663 -3.703797
# 3            Las Palmas -15.521512  28.117496  40.41663 -3.703797
# 4            Las Palmas -15.654111  28.143873  40.41663 -3.703797
# ..                  ...        ...        ...       ...       ...
# 846              Murcia  -1.124304  37.979033  40.41663 -3.703797
# 847              Murcia  -1.202069  37.984024  40.41663 -3.703797
# 848              Murcia  -1.130564  37.995715  40.41663 -3.703797
# 849              Toledo  -3.948364  39.866699  40.41663 -3.703797
# 850  Castelló/Castellón   0.012911  39.973568  40.41663 -3.703797
#
#      distancia_a_madrid
# 0           1758.916528
# 1           1633.121815
# 2           1558.090159
# 3           1743.384274
# 4           1748.530896
# ..                  ...
# 846          350.610570
# 847          345.961743
# 848          348.818236
# 849           64.606934
# 850          319.580006
#
# [851 rows x 13 columns]

# %%
data_8.sort_values(by=['distancia_a_madrid'], ascending=False).head(5)
# Out:
#      FID  OBJECTID                   Texto  Poblacion  CodMun  \
# 29    29        30   Los Llanos de Aridane    20948.0   38024
# 35    35        36  Santa Cruz de la Palma    17128.0   38037
# 764  765       766          Los Cristianos    19383.0   38006
# 763  764       765   Playa de las Américas    18562.0   38001
# 21    21        22                   Adeje    43801.0   38001
#
#                   Municipio  CodProvin               Provincia        X_x  \
# 29    Los Llanos de Aridane         38  Santa Cruz de Tenerife -17.914361
# 35   Santa Cruz de la Palma         38  Santa Cruz de Tenerife -17.765386
# 764                   Arona         38  Santa Cruz de Tenerife -16.716798
# 763                   Adeje         38  Santa Cruz de Tenerife -16.729436
# 21                    Adeje         38  Santa Cruz de Tenerife -16.729708
#
#            Y_x       Y_y       X_y  distancia_a_madrid
# 29   28.658639  40.41663 -3.703797         1840.800324
# 35   28.684138  40.41663 -3.703797         1829.136677
# 764  28.053827  40.41663 -3.703797         1818.686705
# 763  28.068070  40.41663 -3.703797         1818.186369
# 21   28.118880  40.41663 -3.703797         1813.726297

# %% [markdown]
# R. los cinco municipios màs lejanos a Madrid son: Los Llanos de Aridane, Santa Cruz de la Palma, Arona, Adeje, Adeje

# %%
data_8.sort_values(by=['distancia_a_madrid']).head(5)
# Out:
#      FID  OBJECTID                            Texto  Poblacion  CodMun  \
# 782  783       784  Humera-Somosaguas-prado del Rey    14800.0   28115
# 780  781       782                          Fortuna    12840.0   28074
# 364  365       366               Pozuelo de Alarcón    82804.0   28115
# 779  780       781                       El Bercial    12814.0   28065
# 354  354       355                          Leganés   187227.0   28074
#
#               Municipio  CodProvin Provincia       X_x        Y_x       Y_y  \
# 782  Pozuelo de Alarcón         28    Madrid -3.783853  40.428764  40.41663
# 780             Leganés         28    Madrid -3.780326  40.358067  40.41663
# 364  Pozuelo de Alarcón         28    Madrid -3.815816  40.435940  40.41663
# 779              Getafe         28    Madrid -3.736771  40.327270  40.41663
# 354             Leganés         28    Madrid -3.766556  40.331744  40.41663
#
#           X_y  distancia_a_madrid
# 782 -3.703797            6.911934
# 780 -3.703797            9.190723
# 364 -3.703797            9.725121
# 779 -3.703797           10.324749
# 354 -3.703797           10.836540

# %% [markdown]
# R. Los cinco municipios màs cercanos a Madrid son: Pozuelo de Alarcòn, Leganès, Pozuelo de Alarcòn, Getage, Leganès
